# %% [markdown]
# <a href="https://colab.research.google.com/github/yashaswiandhavarapu/GenAI/blob/main/ATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2

# %%
import PyPDF2
def extract_text_from_pdf(pdf_path):
    extracted_text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
          page_text=page.extract_text()
          if page_text:
            extracted_text += page.extract_text()
    return extracted_text
me=extract_text_from_pdf('/content/23PA1A4208-YASHASWI ANDHAVARAPU.pdf')
print(me)
# Out:
# YASHASWI ANDHAVARAPU
# yashaswiandhavarapu51@gmail.com +91 9392951359 Srikakulam, Andhra Pradesh
# Linkedln Github
# PROFILE
# I am a motivated student currently pursuing my B.Tech in Computer Science, seeking an internship
# opportunity to gain practical experience and strengthen my technical and professional skills. I have a good
# foundation in programming, teamwork, and problem-solving, and I am eager to learn new tools and
# contribute to real-time projects.
# EDUCATION
# B.Tech, Vishnu Institute of Technology
# CGPA: 8.322023 – 2027
# Intermediate, Tirumala Junior College
# Percentage: 96.6%2021 – 2023
# SSC, Narayana EM High School
# Percentage:96.6%2020 – 2021
# SKILLS
# Programming Languages
# Java, Python, Sql
# Tools
# Git, GitHub,PowerBI,Tableau,ExcelWeb Devolopment
# HTML,CSS, JavaScript,Firebase
# Soft Skills
# Adaptability,Flexibility, Time
# Management,Communication Skills
# INTERNSHIPS
# Smart Internz, Data Analytics Using TABLEAU
# ...

# %%
from google import genai
client = genai.Client(api_key="AIzaSyA9xSy3J88-Wfd6Byujwmpnertlxtit3b4")

# %%
response=client.models.generate_content(
        model="gemini-2.5-flash",
        contents=(f"here is my context{me},question:give rating of my resume")
    )
print(response.text)
# Out:
# This is a very strong resume for someone currently pursuing their B.Tech, especially given the leadership and achievement sections!
#
# Here's a breakdown of the rating and detailed feedback:
#
# ---
#
# ## Resume Rating: **4/5**
#
# **Reasoning:** You have an excellent foundation with relevant skills, strong academic performance, impressive achievements (especially the hackathons), and significant leadership roles. These elements make your resume stand out for a student. The internships are also relevant and well-described.
#
# However, there are a couple of critical issues related to dates that need immediate attention, which prevent it from being a 5/5.
#
# ---
#
# ## Detailed Feedback
#
# ### **Strengths:**
#
# 1.  **Strong Academic Performance:** Your CGPA and percentages are excellent, showing academic rigor.
# ...

# %%
import os
from flask import Flask,request,jsonify
from google import genai
import PyPDF2

# %%
def parse_resume(resume_text):
    prompt = f"""
You are a resume parser.

Extract:
- Skills
- Experience summary
- Education
- Tools & technologies

Resume:
{resume_text}"""


    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
parse_resume=parse_resume(me)
print(parse_resume)
# Out:
# Here's the extracted information from the resume:
#
# **Skills:**
# *   **Programming Languages:** Java, Python, SQL
# *   **Web Development:** HTML, CSS, JavaScript, Firebase
# *   **Soft Skills:** Adaptability, Flexibility, Time Management, Communication Skills
# *   **Other Skills:** Data Analytics, Data Preprocessing, Problem-solving, Teamwork
#
# **Experience summary:**
# *   **Smart Internz, Data Analytics Using TABLEAU (05/2025 – 07/2025):** Worked with real datasets, cleaned data, created Tableau dashboards to visualize trends, comparisons, and insights, and learned to interpret data for decision-making.
# *   **EduSkills, AIML Virtual Intern (AICTE) (04/2025 – 06/2025):** Completed an intensive virtual internship focused on building scalable data pipelines and implementing machine learning workflows, gaining hands-on experience with data preprocessing using Python.
#
# **Education:**
# ...

# %%
def parse_job_description(jd_text):
    prompt = f"""
Extract:
- Required skills
- Responsibilities
- Preferred qualifications

Job Description:
{jd_text}

Return in bullet points.
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
parse_resume=parse_job_description(me)
print(parse_resume)
# Out:
# It appears you've provided a **resume/CV** rather than a **job description**. I will extract the information requested as if this resume were describing the ideal candidate for a role.
#
# Here's the extraction based on the provided resume:
#
# ### Required Skills
# *   **Programming Languages:** Java, Python, SQL
# *   **Tools:** Git, GitHub, PowerBI, Tableau, Excel
# *   **Web Development:** HTML, CSS, JavaScript, Firebase
# *   **Soft Skills:** Adaptability, Flexibility, Time Management, Communication Skills
# *   **Foundational Skills:** Programming, Teamwork, Problem-solving
# *   Eagerness to learn new tools and contribute to real-time projects
#
# ### Responsibilities
# *   Worked on real datasets and cleaned data for analysis.
# *   Created dashboards in Tableau to show trends, comparisons, and useful insights.
# *   Interpreted data and presented findings for decision-making.
# ...
